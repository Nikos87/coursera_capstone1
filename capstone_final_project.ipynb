# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import requests
import random

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim 

from IPython.display import Image 
from IPython.core.display import HTML 
 
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Solving environment: done
#
# # All requested packages already installed.

# %%
CLIENT_ID = 'EVIKQIRSJ2EM3EXRDX31ZCJV5OXOGQSILSAMFBMLEGCYGWN1' # your Foursquare ID
CLIENT_SECRET = '23FTSO25D0DACRGHETV1KHUAISOIS5DL3MWSLPJUIWYJQ4YB' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: EVIKQIRSJ2EM3EXRDX31ZCJV5OXOGQSILSAMFBMLEGCYGWN1
# CLIENT_SECRET:23FTSO25D0DACRGHETV1KHUAISOIS5DL3MWSLPJUIWYJQ4YB

# %%
address = '1 Iasonidou Avenue, Elliniko, Athens'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 37.8923109 23.7481025

# %%
search_query = 'Night Club'
radius = 10500
print(search_query + ' .... OK!')
# Out:
# Night Club .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=EVIKQIRSJ2EM3EXRDX31ZCJV5OXOGQSILSAMFBMLEGCYGWN1&client_secret=23FTSO25D0DACRGHETV1KHUAISOIS5DL3MWSLPJUIWYJQ4YB&ll=37.8923109,23.7481025&v=20180604&query=Night Club&radius=10500&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e1600f66001fe001bc95159'},
#  'response': {'venues': [{'id': '5d61b9fae767320008605e85',
#     'name': 'Elite Night Club',
#     'location': {'lat': 37.861858,
#      'lng': 23.748731,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.861858,
#        'lng': 23.748731}],
#      'distance': 3390,
#      'postalCode': '166 75',
#      'cc': 'GR',
#      'city': 'Glifadha',
#      'country': 'Ελλάδα',
#      'formattedAddress': ['166 75 Glifadha', 'Ελλάδα']},
#     'categories': [{'id': '4bf58dd8d48988d11f941735',
#       'name': 'Nightclub',
#       'pluralName': 'Nightclubs',
#       'shortName': 'Nightclub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578500336',
#     'hasPerk': False},
#    {'id': '4fb99ca1e4b0c8c408160853',
#     'name': 'Poiothta Night Club',
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d11f941735', 'name': 'N...    False
# 1  [{'id': '4bf58dd8d48988d119941735', 'name': 'H...    False
# 2  [{'id': '4bf58dd8d48988d11f941735', 'name': 'N...    False
# 3  [{'id': '4e39a956bd410d7aed40cbc3', 'name': 'T...    False
# 4  [{'id': '4cce455aebf7b749d5e191f5', 'name': 'S...    False
#
#                          id location.address location.cc location.city  \
# 0  5d61b9fae767320008605e85              NaN          GR      Glifadha
# 1  4fb99ca1e4b0c8c408160853              NaN          GR      Καλλιθέα
# 2  53094032498e679250583d07        Iera Odos          GR         Αθήνα
# 3  4cb96dcabac937049e58e47c  Τριπόλεως 13-41          GR   Αργυρούπολη
# 4  4dcea70e183899ddfad7aa70      33η Οδός 16          GR      Ελληνικό
#
#   location.country location.crossStreet  location.distance  \
# 0           Ελλάδα                  NaN               3390
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name            categories  \
# 0                                    Elite Night Club             Nightclub
# 1                                 Poiothta Night Club            Hookah Bar
# 2                                         2night club             Nightclub
# 3                             Argyroupoli Tennis Club          Tennis Court
# 4                        Champions Mini Football Club          Soccer Field
# 5                            Hippocampus Fitness Club                   Gym
# 6                                     pankration club           Sports Club
# 7                                 Melekos Health Club                   Gym
# 8                         Glyfada Golf Club of Athens           Golf Course
# 9                                       Zambidis Club           College Gym
# 10                           Παγκράτιο Club Ελληνικού    Athletics & Sports
# ...

# %%
dataframe_filtered.name
# Out:
# 0                                      Elite Night Club
# 1                                   Poiothta Night Club
# 2                                           2night club
# 3                               Argyroupoli Tennis Club
# 4                          Champions Mini Football Club
# 5                              Hippocampus Fitness Club
# 6                                       pankration club
# 7                                   Melekos Health Club
# 8                           Glyfada Golf Club of Athens
# 9                                         Zambidis Club
# 10                             Παγκράτιο Club Ελληνικού
# 11                                  Nike+ Training Club
# 12                    Hwa Rang Tang Soo Do - Kappa Club
# 13                                           cosmo club
# 14                                            Etal Club
# 15                         Astir Beach Club Vouliagmeni
# 16                                      Star Sport Club
# ...

# %%
search_query1 = 'fast food'
radius = 10500
print(search_query1 + ' .... OK!')
# Out:
# fast food .... OK!

# %%
url1 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query1, radius, LIMIT)
url1
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=EVIKQIRSJ2EM3EXRDX31ZCJV5OXOGQSILSAMFBMLEGCYGWN1&client_secret=23FTSO25D0DACRGHETV1KHUAISOIS5DL3MWSLPJUIWYJQ4YB&ll=37.8923109,23.7481025&v=20180604&query=fast food&radius=10500&limit=30'

# %%
results1 = requests.get(url1).json()
results1
# Out:
# {'meta': {'code': 200, 'requestId': '5e16028c47e0d600253efa3d'},
#  'response': {'venues': [{'id': '5263c04611d21121a00007de',
#     'name': 'Sheik Fast Food',
#     'location': {'address': 'Voulgari 8-10',
#      'lat': 37.983573455284485,
#      'lng': 23.723987683761788,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.983573455284485,
#        'lng': 23.723987683761788}],
#      'distance': 10377,
#      'postalCode': '104 37',
#      'cc': 'GR',
#      'city': 'Αθήνα',
#      'state': 'Αττική',
#      'country': 'Ελλάδα',
#      'formattedAddress': ['Voulgari 8-10', '104 37 Αθήνα, Αττική', 'Ελλάδα']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578500790',
#     'hasPerk': False},
# ...

# %%
# assign relevant part of JSON to venues
venues1 = results1['response']['venues']

# tranform venues into a dataframe
dataframe1 = json_normalize(venues1)
dataframe1.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 1  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
# 2  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
# 3  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 4  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
#
#                          id location.address location.cc location.city  \
# 0  5263c04611d21121a00007de    Voulgari 8-10          GR         Αθήνα
# 1  4dd7b5c07d8b322663f5b682        Ιερά Οδός          GR         Αθήνα
# 2  525419af498e79c217058cb8              NaN          GR           NaN
# 3  4f34cab8e4b0c48478e7f555              NaN          GR           NaN
# 4  5773e5e1498e7fbe045a8c62              NaN          GR           NaN
#
#   location.country location.crossStreet  location.distance  \
# 0           Ελλάδα                  NaN              10377
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns1 = ['name', 'categories'] + [col for col in dataframe1.columns if col.startswith('location.')] + ['id']
dataframe_filtered1 = dataframe1.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list1 = row['categories']
    except:
        categories_list1 = row['venue.categories']
        
    if len(categories_list1) == 0:
        return None
    else:
        return categories_list1[0]['name']

# filter the category for each row
dataframe_filtered1['categories'] = dataframe_filtered1.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered1.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered1
# Out:
#                                name                  categories  \
# 0                   Sheik Fast Food                  Restaurant
# 1                   Enter Fast Food        Fast Food Restaurant
# 2                Kassinas Fast Food        Fast Food Restaurant
# 3      The best-fast food-snack bar                        Café
# 4                       Fast Coffee                        Café
# 5                  Fast Hairstyling     Health & Beauty Service
# 6                M&S Food Satellite           Food & Drink Shop
# 7                        Fresh Food        Fast Food Restaurant
# 8                   Fast Fit Studio        Gym / Fitness Center
# 9                           In Situ        Fast Food Restaurant
# 10      Fast & Curious Escape Rooms       General Entertainment
# 11              Fast and Fresh Food        Fast Food Restaurant
# 12               Gaspar Food & Mood                         Bar
# 13                         food lab                    Creperie
# ...

# %%
dataframe_filtered1.name
# Out:
# 0     Crepaland Glyfada (Crepaland Γλυφάδα)
# 1                               Crepa Crepa
# 2                                Crepa Land
# 3                               Crepa-Crepa
# 4                              Crepa Corner
# 5                               Crepa-Crepa
# 6                                 Crepa mou
# 7                                 Crepa Sun
# 8                                     Crepa
# 9                                Crepa Land
# 10                               crepa hour
# 11                               Crepa Land
# 12                              crepa crepa
# 13                              Crepa Queen
# 14                            Crepa Melissa
# 15            Crepa House - The Coffee Spot
# 16                                Crepa Mad
# 17                             crepa di piu
# 18                             Arte e crepa
# 19                                Crepa Way
# 20                             magica crepa
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Center of our interest area
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='green',
    popup='Center',
    fill = True,
    fill_color = 'green',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Night Clubs as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# add the Sandwitch restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered1.lat, dataframe_filtered1.lng, dataframe_filtered1.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='red',
        popup=label,
        fill = True,
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
